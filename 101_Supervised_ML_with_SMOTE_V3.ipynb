# %% [markdown]
# ## Library Imports and Configuration

# %%
# Importing required libraries for data handling and visualization
import pandas as pd  # Data manipulation and analysis
import numpy as np  # Numerical operations
import matplotlib.pyplot as plt  # Plotting and visualization
import seaborn as sns  # Advanced data visualization

from imblearn.over_sampling import SMOTE

# Importing machine learning libraries for preprocessing and model building
from sklearn.preprocessing import StandardScaler  # Feature scaling
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV  # Hyperparameter optimization
from sklearn.tree import DecisionTreeClassifier  # Decision tree model
from sklearn.ensemble import RandomForestClassifier  # Random forest model
from sklearn.svm import SVC  # Import SVC
from xgboost import XGBClassifier  # XGBoost model
import xgboost as xgb  # XGBoost library
from lightgbm import LGBMClassifier  # LightGBM model
import lightgbm as lgb  # LightGBM library
from sklearn.ensemble import GradientBoostingClassifier  # Gradient boosting model
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split

# Importing performance metrics for model evaluatio
from sklearn.metrics import roc_curve  # ROC curve computation
from sklearn.metrics import auc  # Area under curve calculation
from sklearn.metrics import confusion_matrix  # Confusion matrix computation
# Import performance metrics from sklearn
from sklearn.metrics import roc_auc_score, accuracy_score, classification_report # Summary report of precision, recall, F1
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.preprocessing import label_binarize
from sklearn.metrics import log_loss

# Configurations to suppress warnings and control logging
import warnings
warnings.filterwarnings('ignore')  # Ignore warnings to clean up notebook output
warnings.filterwarnings("ignore", category=UserWarning)  # Specific warning category to ignore
warnings.filterwarnings("ignore", category=DeprecationWarning)  # Ignore deprecation warnings
import logging
logging.getLogger('lightgbm').setLevel(logging.INFO)  # Set logging level for LightGBM
logging.getLogger('lightgbm').setLevel(logging.ERROR)  # Set logging level for LightGBM

# %%
import os
os.environ["OMP_NUM_THREADS"] = "3"
os.environ["MKL_NUM_THREADS"] = "3"
print(os.getcwd())
# Out:
# /users/emmanuel/Msc

# %% [markdown]
# ### Loading the datasets and Annotation File

# %%
# Load the gene level expression matrix eset_HTA20. 
hta_df = pd.read_csv("HTA20_RMA.xlsx", sep = " ")
hta_df.head()
# Out:
#           Tarca_001_P1A01  Tarca_003_P1A03  Tarca_004_P1A04  Tarca_005_P1A05  \
# 1_at             6.062215         6.125023         5.875502         6.126131
# 10_at            3.796484         3.805305         3.450245         3.628411
# 100_at           5.849338         6.191562         6.550525         6.421877
# 1000_at          3.567779         3.452524         3.316134         3.432451
# 10000_at         6.166815         5.678373         6.185059         5.633757
#
#           Tarca_006_P1A06  Tarca_007_P1A07  Tarca_008_P1A08  Tarca_011_P1A11  \
# 1_at             6.146466         6.134555         6.289534         6.320997
# 10_at            3.446812         3.512325         3.568193         3.584622
# 100_at           6.260962         6.154893         6.348074         6.175742
# 1000_at          3.477162         3.638140         3.399044         3.787394
# 10000_at         5.313198         5.148149         5.640643         5.270906
#
#           Tarca_012_P1A12  Tarca_013_P1B01  ...  Tarca_911_P10G06  \
# 1_at             6.185504         6.085618  ...          6.123887
# 10_at            3.696258         3.549118  ...          3.642128
# 100_at           6.179713         6.117801  ...          6.216938
# 1000_at          3.452014         3.542147  ...          3.579528
# 10000_at         5.694625         6.257552  ...          5.733829
#
#           Tarca_912_P10H06  Tarca_913_P10A07  Tarca_914_P10B07  \
# 1_at              6.092937          6.374775          6.199526
# 10_at             3.543872          4.165844          3.725332
# 100_at            6.161236          6.371440          6.181719
# 1000_at           3.509152          3.654649          3.760908
# 10000_at          5.913966          5.650307          5.630868
#
#           Tarca_915_P10C07  Tarca_916_P10D07  Tarca_917_P10E07  \
# 1_at              6.244360          6.277895          6.365038
# 10_at             3.536598          3.708818          3.773754
# 100_at            6.195250          6.276257          6.221597
# 1000_at           3.601202          3.763030          3.775920
# 10000_at          5.488366          5.424940          5.350965
#
#           Tarca_918_P10F07  Tarca_919_P10G07  Tarca_920_P10H07
# 1_at              6.341189          6.433980          6.254807
# 10_at             3.970478          3.749549          3.599263
# 100_at            6.186570          6.213764          6.329449
# 1000_at           3.712024          3.769967          3.718142
# 10000_at          5.605535          5.379500          5.513927
#
# [5 rows x 735 columns]

# %%
hta_df.shape
# Out:
# (32830, 735)

# %%
#Loading the the gene level expression matrix esetHuGene21ST (29,635 rows x 326 columns) for dataset GSE59491
gsm_df = pd.read_csv("GSM_train.csv")

# %%
gsm_df.head()
# Out:
#   Unnamed: 0  GSM1437801  GSM1437802  GSM1437803  GSM1437804  GSM1437805  \
# 0       1_at    4.865497    4.873023    4.786624    4.366512    4.627092
# 1      10_at    2.454080    3.124465    2.814248    2.479630    2.555347
# 2     100_at    7.977459    7.841581    8.605167    8.450711    7.896053
# 3    1000_at    4.163376    4.317975    3.846657    4.210707    4.321997
# 4   10000_at    7.117694    7.306302    7.046300    7.115633    6.695250
#
#    GSM1437806  GSM1437807  GSM1437808  GSM1437809  ...  GSM1438117  \
# 0    5.022471    5.001928    5.292825    4.547198  ...    5.446590
# 1    2.434593    2.378920    2.234354    2.488600  ...    2.257441
# 2    8.148322    8.262210    8.395612    8.200204  ...    8.248806
# 3    4.185616    3.919003    3.970493    4.415479  ...    3.454188
# 4    6.680977    7.018231    6.880931    6.775556  ...    7.276332
#
#    GSM1438118  GSM1438119  GSM1438120  GSM1438121  GSM1438122  GSM1438123  \
# 0    5.021293    4.711062    4.704052    4.469233    4.664661    4.962359
# 1    2.343328    2.268315    2.581067    2.558224    2.570164    2.643409
# 2    8.301371    7.965852    8.316221    8.494200    8.510477    8.616120
# 3    4.134260    4.108867    3.966018    3.838453    3.484688    3.934110
# 4    6.933368    6.714113    6.905420    6.996540    7.504992    7.144397
#
#    GSM1438124  GSM1438125  GSM1438126
# 0    4.674659    4.587906    4.821703
# 1    2.327913    2.494115    2.370691
# 2    8.483724    8.831870    8.373812
# 3    3.903856    3.992998    3.987127
# 4    7.044756    6.735834    6.761954
#
# [5 rows x 327 columns]

# %%
gsm_df.shape
# Out:
# (29635, 327)

# %%
#Reset the index to 'Unnamed: 0' ... Ths will ensure that this set of train datasets have the same index as those in hta_df
gsm_df1= gsm_df.set_index('Unnamed: 0') # This will allow us to use the index as refrence for merging the datasets.
gsm_df1.head()
# Out:
#             GSM1437801  GSM1437802  GSM1437803  GSM1437804  GSM1437805  \
# Unnamed: 0
# 1_at          4.865497    4.873023    4.786624    4.366512    4.627092
# 10_at         2.454080    3.124465    2.814248    2.479630    2.555347
# 100_at        7.977459    7.841581    8.605167    8.450711    7.896053
# 1000_at       4.163376    4.317975    3.846657    4.210707    4.321997
# 10000_at      7.117694    7.306302    7.046300    7.115633    6.695250
#
#             GSM1437806  GSM1437807  GSM1437808  GSM1437809  GSM1437810  ...  \
# Unnamed: 0                                                              ...
# 1_at          5.022471    5.001928    5.292825    4.547198    4.713176  ...
# 10_at         2.434593    2.378920    2.234354    2.488600    2.456773  ...
# 100_at        8.148322    8.262210    8.395612    8.200204    8.639295  ...
# 1000_at       4.185616    3.919003    3.970493    4.415479    4.226394  ...
# 10000_at      6.680977    7.018231    6.880931    6.775556    6.608307  ...
#
#             GSM1438117  GSM1438118  GSM1438119  GSM1438120  GSM1438121  \
# Unnamed: 0
# 1_at          5.446590    5.021293    4.711062    4.704052    4.469233
# 10_at         2.257441    2.343328    2.268315    2.581067    2.558224
# 100_at        8.248806    8.301371    7.965852    8.316221    8.494200
# 1000_at       3.454188    4.134260    4.108867    3.966018    3.838453
# 10000_at      7.276332    6.933368    6.714113    6.905420    6.996540
#
#             GSM1438122  GSM1438123  GSM1438124  GSM1438125  GSM1438126
# Unnamed: 0
# 1_at          4.664661    4.962359    4.674659    4.587906    4.821703
# 10_at         2.570164    2.643409    2.327913    2.494115    2.370691
# 100_at        8.510477    8.616120    8.483724    8.831870    8.373812
# 1000_at       3.484688    3.934110    3.903856    3.992998    3.987127
# 10000_at      7.504992    7.144397    7.044756    6.735834    6.761954
#
# [5 rows x 326 columns]

# %%
#Merge the two datasets to obatin a comphresive dataset "data"
data = hta_df.merge(gsm_df1, left_index=True, right_index=True, how="inner")

# %%
data
# Out:
#           Tarca_001_P1A01  Tarca_003_P1A03  Tarca_004_P1A04  Tarca_005_P1A05  \
# 1_at             6.062215         6.125023         5.875502         6.126131
# 10_at            3.796484         3.805305         3.450245         3.628411
# 100_at           5.849338         6.191562         6.550525         6.421877
# 1000_at          3.567779         3.452524         3.316134         3.432451
# 10000_at         6.166815         5.678373         6.185059         5.633757
# ...                   ...              ...              ...              ...
# 9991_at          9.700440         9.271577         9.470850         9.374321
# 9992_at          3.771009         3.838563         3.568739         3.691639
# 9993_at          8.227688         8.083417         7.983239         8.270554
# 9994_at          5.992462         5.826221         6.175550         5.635078
# 9997_at          7.220196         7.440989         7.331443         7.298491
#
#           Tarca_006_P1A06  Tarca_007_P1A07  Tarca_008_P1A08  Tarca_011_P1A11  \
# 1_at             6.146466         6.134555         6.289534         6.320997
# 10_at            3.446812         3.512325         3.568193         3.584622
# 100_at           6.260962         6.154893         6.348074         6.175742
# 1000_at          3.477162         3.638140         3.399044         3.787394
# 10000_at         5.313198         5.148149         5.640643         5.270906
# ...                   ...              ...              ...              ...
# 9991_at          9.267968         9.626822         9.270385         9.367872
# 9992_at          3.758960         3.775041         3.726264         3.857164
# 9993_at          8.012785         8.575628         7.972229         8.241322
# 9994_at          5.740465         5.628403         5.994099         5.897324
# 9997_at          7.413392         7.480904         7.427693         7.459319
#
#           Tarca_012_P1A12  Tarca_013_P1B01  ...  GSM1438117  GSM1438118  \
# 1_at             6.185504         6.085618  ...    5.446590    5.021293
# 10_at            3.696258         3.549118  ...    2.257441    2.343328
# 100_at           6.179713         6.117801  ...    8.248806    8.301371
# 1000_at          3.452014         3.542147  ...    3.454188    4.134260
# 10000_at         5.694625         6.257552  ...    7.276332    6.933368
# ...                   ...              ...  ...         ...         ...
# 9991_at          9.321996         9.633982  ...   11.258341   11.346868
# 9992_at          3.706270         3.653025  ...    2.662402    2.860640
# 9993_at          7.888280         8.120547  ...    9.948764   10.306209
# 9994_at          6.117054         6.226442  ...    7.624515    7.132689
# 9997_at          7.511730         7.321457  ...    6.725144    6.527672
#
#           GSM1438119  GSM1438120  GSM1438121  GSM1438122  GSM1438123  \
# 1_at        4.711062    4.704052    4.469233    4.664661    4.962359
# 10_at       2.268315    2.581067    2.558224    2.570164    2.643409
# 100_at      7.965852    8.316221    8.494200    8.510477    8.616120
# 1000_at     4.108867    3.966018    3.838453    3.484688    3.934110
# 10000_at    6.714113    6.905420    6.996540    7.504992    7.144397
# ...              ...         ...         ...         ...         ...
# 9991_at    11.374917   11.381557   11.328234   11.303358   11.209462
# 9992_at     3.068664    3.107949    3.090471    2.889210    2.849657
# 9993_at    10.345557   10.058155   10.126526   10.128585    9.829649
# 9994_at     7.364539    7.482933    7.350082    7.966744    7.793764
# 9997_at     6.504655    6.581656    6.991313    7.029418    6.501659
#
#           GSM1438124  GSM1438125  GSM1438126
# 1_at        4.674659    4.587906    4.821703
# 10_at       2.327913    2.494115    2.370691
# 100_at      8.483724    8.831870    8.373812
# 1000_at     3.903856    3.992998    3.987127
# 10000_at    7.044756    6.735834    6.761954
# ...              ...         ...         ...
# 9991_at    11.341351   11.455903   11.355943
# 9992_at     3.041607    3.307009    3.020891
# 9993_at     9.972865   10.181318   10.089825
# 9994_at     7.324079    6.918412    7.584111
# 9997_at     6.773428    7.531117    7.340730
#
# [29459 rows x 1061 columns]

# %%
# Load the sample annotation file i.e Dataset Key.. 
dataset_key = pd.read_csv("anoSC2_v20_nokey.csv")

# %%
dataset_key.shape
# Out:
# (739, 9)

# %% [markdown]
# ###  Dataset Preparation
# Only samples stated in the annotation file (i.e Dataset Key)"anoSC2_v20_nokey.csv"  will be used in our dataset.
# In order to ensure that only samples in dataset key are selected from the data, we shall now follow the following steps.

# %%
# Get the list of SampleIDs where Train is 1 
Valid_train_IDS = dataset_key.loc[dataset_key["Train"] == 1, "SampleID"]
# Ensure that you select from "data" only columns that exist in dataset_Key
IDS_in_key = Valid_train_IDS[Valid_train_IDS.isin(data.columns)]
#Create a datframe of only those samples whose ID is in datakey provided.. 
data_df = data[IDS_in_key]
data_df.head()
# Out:
#           GSM1437802  GSM1437801  GSM1437804  GSM1437803  GSM1437806  \
# 1_at        4.873023    4.865497    4.366512    4.786624    5.022471
# 10_at       3.124465    2.454080    2.479630    2.814248    2.434593
# 100_at      7.841581    7.977459    8.450711    8.605167    8.148322
# 1000_at     4.317975    4.163376    4.210707    3.846657    4.185616
# 10000_at    7.306302    7.117694    7.115633    7.046300    6.680977
#
#           GSM1437805  GSM1437808  GSM1437807  GSM1437810  GSM1437809  ...  \
# 1_at        4.627092    5.292825    5.001928    4.713176    4.547198  ...
# 10_at       2.555347    2.234354    2.378920    2.456773    2.488600  ...
# 100_at      7.896053    8.395612    8.262210    8.639295    8.200204  ...
# 1000_at     4.321997    3.970493    3.919003    4.226394    4.415479  ...
# 10000_at    6.695250    6.880931    7.018231    6.608307    6.775556  ...
#
#           Tarca_597_P7E03  Tarca_641_P7A09  Tarca_492_P6D02  Tarca_491_P6C02  \
# 1_at             6.199299         6.334521         5.670749         5.875766
# 10_at            3.706720         3.836938         3.227989         3.554173
# 100_at           6.179244         6.152893         6.369151         6.495599
# 1000_at          3.514861         3.604500         3.437909         3.455021
# 10000_at         5.053029         5.249306         6.073804         6.075164
#
#           Tarca_506_P6B04  Tarca_920_P10H07  Tarca_919_P10G07  \
# 1_at             6.112121          6.254807          6.433980
# 10_at            3.521487          3.599263          3.749549
# 100_at           6.481665          6.329449          6.213764
# 1000_at          3.520653          3.718142          3.769967
# 10000_at         5.661452          5.513927          5.379500
#
#           Tarca_918_P10F07  Tarca_917_P10E07  Tarca_916_P10D07
# 1_at              6.341189          6.365038          6.277895
# 10_at             3.970478          3.773754          3.708818
# 100_at            6.186570          6.221597          6.276257
# 1000_at           3.712024          3.775920          3.763030
# 10000_at          5.605535          5.350965          5.424940
#
# [5 rows x 435 columns]

# %%
#merge the dataset "data_df" with the dataset Key based on sample IDS 
# Set SampleID as the index in dataset_key
dataset_key.set_index('SampleID', inplace=True)

# Transpose data_df and merge with dataset_key
data_with_key = data_df.transpose().merge(dataset_key, left_index=True, right_index=True, how="inner")

data_with_key.head()
# Out:
#                 1_at     10_at    100_at   1000_at  10000_at  100009613_at  \
# GSM1437802  4.873023  3.124465  7.841581  4.317975  7.306302      3.889792
# GSM1437801  4.865497  2.454080  7.977459  4.163376  7.117694      3.195365
# GSM1437804  4.366512  2.479630  8.450711  4.210707  7.115633      3.390626
# GSM1437803  4.786624  2.814248  8.605167  3.846657  7.046300      2.991461
# GSM1437806  5.022471  2.434593  8.148322  4.185616  6.680977      3.420477
#
#             100009676_at  10001_at  10002_at  10003_at  ...   9994_at  \
# GSM1437802      7.116418  7.934444  3.938398  2.162576  ...  7.967755
# GSM1437801      6.923813  7.705731  4.337360  2.457066  ...  7.420243
# GSM1437804      6.928906  7.920388  4.051784  2.547550  ...  7.655429
# GSM1437803      7.028040  7.790158  4.319769  2.276823  ...  7.527143
# GSM1437806      6.673671  7.713025  4.276860  2.097956  ...  7.096773
#
#              9997_at  IndividualID    GA  GADel    Group       Set  Train  \
# GSM1437802  7.308521        515122  28.0   40.0  Control  GSE59491      1
# GSM1437801  7.366170        515122  19.0   40.0  Control  GSE59491      1
# GSM1437804  6.665448        810384  28.0   40.0  Control  GSE59491      1
# GSM1437803  6.837073        810384  18.0   40.0  Control  GSE59491      1
# GSM1437806  7.262304        810392  28.0   41.0  Control  GSE59491      1
#
#             Platform   TTD
# GSM1437802    HG21ST  12.0
# GSM1437801    HG21ST  21.0
# GSM1437804    HG21ST  12.0
# GSM1437803    HG21ST  22.0
# GSM1437806    HG21ST  13.0
#
# [5 rows x 29467 columns]

# %%
data_with_key
# Out:
#                       1_at     10_at    100_at   1000_at  10000_at  \
# GSM1437802        4.873023  3.124465  7.841581  4.317975  7.306302
# GSM1437801        4.865497  2.454080  7.977459  4.163376  7.117694
# GSM1437804        4.366512  2.479630  8.450711  4.210707  7.115633
# GSM1437803        4.786624  2.814248  8.605167  3.846657  7.046300
# GSM1437806        5.022471  2.434593  8.148322  4.185616  6.680977
# ...                    ...       ...       ...       ...       ...
# Tarca_920_P10H07  6.254807  3.599263  6.329449  3.718142  5.513927
# Tarca_919_P10G07  6.433980  3.749549  6.213764  3.769967  5.379500
# Tarca_918_P10F07  6.341189  3.970478  6.186570  3.712024  5.605535
# Tarca_917_P10E07  6.365038  3.773754  6.221597  3.775920  5.350965
# Tarca_916_P10D07  6.277895  3.708818  6.276257  3.763030  5.424940
#
#                   100009613_at  100009676_at  10001_at  10002_at  10003_at  \
# GSM1437802            3.889792      7.116418  7.934444  3.938398  2.162576
# GSM1437801            3.195365      6.923813  7.705731  4.337360  2.457066
# GSM1437804            3.390626      6.928906  7.920388  4.051784  2.547550
# GSM1437803            2.991461      7.028040  7.790158  4.319769  2.276823
# GSM1437806            3.420477      6.673671  7.713025  4.276860  2.097956
# ...                        ...           ...       ...       ...       ...
# Tarca_920_P10H07      4.799670      5.786147  5.912813  4.794894  2.638680
# Tarca_919_P10G07      4.702771      6.341635  5.630483  5.081581  2.768239
# Tarca_918_P10F07      4.955071      6.078098  5.797294  4.819776  2.662060
# Tarca_917_P10E07      5.047696      6.233094  5.556679  4.806731  2.731038
# Tarca_916_P10D07      4.780348      6.266113  5.604258  4.866926  2.726486
#
#                   ...   9994_at   9997_at  IndividualID    GA  GADel    Group  \
# GSM1437802        ...  7.967755  7.308521        515122  28.0  40.00  Control
# GSM1437801        ...  7.420243  7.366170        515122  19.0  40.00  Control
# GSM1437804        ...  7.655429  6.665448        810384  28.0  40.00  Control
# GSM1437803        ...  7.527143  6.837073        810384  18.0  40.00  Control
# GSM1437806        ...  7.096773  7.262304        810392  28.0  41.00  Control
# ...               ...       ...       ...           ...   ...    ...      ...
# Tarca_920_P10H07  ...  5.619030  7.483330         27755  30.0  30.29     sPTD
# Tarca_919_P10G07  ...  5.667191  7.542290         27755  28.1  30.29     sPTD
# Tarca_918_P10F07  ...  5.759987  7.486573         27755  26.1  30.29     sPTD
# Tarca_917_P10E07  ...  5.602169  7.599404         27755  24.0  30.29     sPTD
# Tarca_916_P10D07  ...  5.597735  7.484533         27755  21.0  30.29     sPTD
#
#                        Set  Train  Platform   TTD
# GSM1437802        GSE59491      1    HG21ST  12.0
# GSM1437801        GSE59491      1    HG21ST  21.0
# GSM1437804        GSE59491      1    HG21ST  12.0
# GSM1437803        GSE59491      1    HG21ST  22.0
# GSM1437806        GSE59491      1    HG21ST  13.0
# ...                    ...    ...       ...   ...
# Tarca_920_P10H07   PRB_HTA      1     HTA20   0.3
# Tarca_919_P10G07   PRB_HTA      1     HTA20   2.2
# Tarca_918_P10F07   PRB_HTA      1     HTA20   4.2
# Tarca_917_P10E07   PRB_HTA      1     HTA20   6.3
# Tarca_916_P10D07   PRB_HTA      1     HTA20   9.3
#
# [435 rows x 29467 columns]

# %%
data_with_key.shape
# Out:
# (435, 29467)

# %%
#checking for missing values in the dataset
data_with_key.isnull().sum()
# Out:
# 1_at        0
# 10_at       0
# 100_at      0
# 1000_at     0
# 10000_at    0
#            ..
# Group       0
# Set         0
# Train       0
# Platform    0
# TTD         0
# Length: 29467, dtype: int64

# %%
# Remove duplicate rows from the training data to ensure that the model learns from unique examples
data_with_key = data_with_key.drop_duplicates()

# Print the new shape of the training data after cleaning to confirm the changes
print("shape of the data :", data_with_key.shape)
# Out:
# shape of the data : (435, 29467)

# %%
# Display the distribution of the target variable 'Group'
print(data_with_key['Group'].value_counts())

# Set the figure size
plt.figure(figsize=(4,2))
# Create a count plot to visualize the number of observations for each 'Group' class,
sns.countplot(x='Group', data=data_with_key)

# Display the plot
plt.show()
# Out:
# Group
# Control    285
# PPROM       95
# sPTD        55
# Name: count, dtype: int64

# %% [markdown]
# ## Preparing Data for modeling

# %% [markdown]
# ### Splitting Dataset

# %%
#The index (representing different sampleIDs) often does not serve as a feature for predictive models 
# We shall therefore drop it from our dataset. 

data_with_key = data_with_key.reset_index(drop=True)  # Drop the index

print("shape of the our data :", data_with_key.shape ) #To confirm that it doesnt change the shape of our datasets.
# Out:
# shape of the our data : (435, 29467)

# %%
X = data_with_key.drop(columns=['IndividualID','GA','GADel','Group','Set','Train','Platform','TTD'])
y = data_with_key['Group']

# %%
X.head()
# Out:
#        1_at     10_at    100_at   1000_at  10000_at  100009613_at  \
# 0  4.873023  3.124465  7.841581  4.317975  7.306302      3.889792
# 1  4.865497  2.454080  7.977459  4.163376  7.117694      3.195365
# 2  4.366512  2.479630  8.450711  4.210707  7.115633      3.390626
# 3  4.786624  2.814248  8.605167  3.846657  7.046300      2.991461
# 4  5.022471  2.434593  8.148322  4.185616  6.680977      3.420477
#
#    100009676_at  10001_at  10002_at  10003_at  ...    9987_at   9988_at  \
# 0      7.116418  7.934444  3.938398  2.162576  ...  10.140315  9.806943
# 1      6.923813  7.705731  4.337360  2.457066  ...   9.553146  9.304134
# 2      6.928906  7.920388  4.051784  2.547550  ...  10.002533  9.349997
# 3      7.028040  7.790158  4.319769  2.276823  ...  10.066194  9.497438
# 4      6.673671  7.713025  4.276860  2.097956  ...   9.383400  9.143473
#
#      9989_at    999_at    9990_at    9991_at   9992_at    9993_at   9994_at  \
# 0  10.127010  5.766303  10.940417  11.098387  3.053534  10.279052  7.967755
# 1  10.364049  6.928753  11.058097  11.385048  2.668465  10.258012  7.420243
# 2  10.064581  6.280449  10.915911  11.246241  2.792030  10.091671  7.655429
# 3   9.917653  5.970615  10.833824  11.225455  3.076462  10.023860  7.527143
# 4   9.776344  7.394728  10.834272  11.207113  3.742716  10.189299  7.096773
#
#     9997_at
# 0  7.308521
# 1  7.366170
# 2  6.665448
# 3  6.837073
# 4  7.262304
#
# [5 rows x 29459 columns]

# %%
y
# Out:
# 0      Control
# 1      Control
# 2      Control
# 3      Control
# 4      Control
#         ...
# 430       sPTD
# 431       sPTD
# 432       sPTD
# 433       sPTD
# 434       sPTD
# Name: Group, Length: 435, dtype: object

# %%
# Import the LabelEncoder from sklearn for encoding categorical variables
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
# Fit the LabelEncoder to the target variable and transform it to a numeric format
y = labelencoder.fit_transform(y)

# %%
# Initial Split: Split the data into training (70%) and test (30%) sets.
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=0)

#SMOTE (Synthetic Minority Over-sampling Technique) from the imblearn library 
#for handling imbalanced datasets by generating synthetic samples for the minority classes.
# Apply SMOTE to the training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Data augmentation on the SMOTE-augmented training data
def augment_data(X, y, augmentation_factor=1.0, batch_size=1000):
    """Augment the dataset by adding small variations to the gene expression levels."""
    means = np.mean(X, axis=0)
    stds = np.std(X, axis=0)

    total_augmented = int(augmentation_factor * len(X))
    augmented_X = []
    augmented_y = []

    for _ in range(total_augmented // batch_size + 1):
        current_batch_size = min(batch_size, total_augmented - len(augmented_X) * batch_size)
        if current_batch_size <= 0:
            break
        
        batch_noise = np.random.normal(0, stds * 0.1, size=(current_batch_size, X.shape[1]))
        new_data = X[:current_batch_size] + batch_noise
        augmented_X.append(new_data)
        augmented_y.append(y[:current_batch_size])

    return np.vstack(augmented_X), np.concatenate(augmented_y)

# Augment the SMOTE-augmented training data
X_augmented, y_augmented = augment_data(X_train_smote, y_train_smote, augmentation_factor=1.0)
X_train = np.vstack((X_train_smote, X_augmented))
y_train = np.concatenate((y_train_smote, y_augmented))

# Further split the training data into training (80% of the 70%) and validation (20% of the 70%) sets.
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# Print the shapes of the datasets to confirm the split
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
print(f"X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
# Out:
# X_train shape: (955, 29459), y_train shape: (955,)
# X_val shape: (239, 29459), y_val shape: (239,)
# X_test shape: (131, 29459), y_test shape: (131,)

# %% [markdown]
# ## Model Training and Evaluation

# %%
#Normalization of Expression Data
# Scaling the features for models like SVM that require it
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# Convert X_train and X_val to DataFrame to include feature names as feature names are required by LGBMClassifier
feature_columns = X.columns  
X_train_df = pd.DataFrame(X_train, columns=feature_columns)
X_val_df = pd.DataFrame(X_val, columns=feature_columns)

# %%
# Dictionary of machine learning models for multi-class classification
models = {
    'DecisionTree': DecisionTreeClassifier(),
    'RandomForest': RandomForestClassifier(),
    'XGBClassifier': XGBClassifier(eval_metric='mlogloss', verbosity=1),
    'LGBMClassifier': LGBMClassifier(verbosity=-1),
    'GradientBoostingClassifier': GradientBoostingClassifier(),
    'SVM': SVC(probability=True)  # Enable probability estimates
}

param_grids = {
    'DecisionTree': {
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10]
    },
    'RandomForest': {
        'n_estimators': [50, 100, 200, 300, 500],
        'max_depth': [None, 10, 20, 30],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf': [1, 2, 4],
        'max_features': ['sqrt', 'log2'],
        'bootstrap': [True, False]
    },
    'XGBClassifier': {
        'n_estimators': [100, 200],
        'max_depth': [3, 5, 7],
        'learning_rate': [0.01, 0.1, 0.2]
    },
    'LGBMClassifier': {
        'n_estimators': [100, 200],
        'max_depth': [3, 4], 
        'learning_rate': [0.1, 0.2],
    },
    'GradientBoostingClassifier': {
        'n_estimators': [100, 200],
        'learning_rate': [0.2, 0.3, 0.4],
        'max_depth': [3, 5, 7]
    },
    'SVM': {
        'C': [0.1, 1, 10],
        'gamma': ['scale', 'auto']
    }
}
# Dictionary to store performance metrics for each model
model_metrics = {}

# Dictionary to store loss curves for each model
loss_curves = {}

# Dictionary to store confusion matrices for each model
confusion_matrices = {}

# Dictionary to store ROC curve data for each model
roc_curves = {}

# Dictionary to store the best models after tuning
best_models = {}

# Train and evaluate each model
for name, model in models.items():
    print(f"Training {name} with hyperparameter tuning...")
    
    # Choose the appropriate parameter grid
    param_grid = param_grids.get(name, {})
    
    # Set up GridSearchCV
    search = GridSearchCV(model, param_grid, cv=5, scoring='roc_auc_ovr', n_jobs=-1, verbose=1)
    
    # Use scaled data for SVM, otherwise use unscaled data
    if name == 'SVM':
        X_train_data = X_train_scaled  # Use scaled data for SVM
        X_val_data = X_val_scaled
    elif name == 'LGBMClassifier':
        X_train_data = X_train_df  # Use DataFrame with feature names for LGBM
        X_val_data = X_val_df
    else:
        X_train_data = X_train  # Use unscaled data for other models
        X_val_data = X_val
    
    # Train the model using GridSearchCV
    search.fit(X_train_data, y_train)
    
    # Store the best model
    best_models[name] = search.best_estimator_
    
    # Predict on the validation set
    val_preds = best_models[name].predict(X_val_data)
    
    # Get probability estimates for each class (required for AUC calculation)
    val_probs = best_models[name].predict_proba(X_val_data)
    
    # Calculate accuracy for the validation set
    val_accuracy = accuracy_score(y_val, val_preds)
    
    # Calculate the AUC score using the One-vs-Rest scheme for multi-class scenarios
    val_roc_auc = roc_auc_score(y_val, val_probs, multi_class='ovr', average='weighted')
    
    # Store accuracy and AUC in the metrics dictionary
    model_metrics[name] = {
        'Best Params': search.best_params_,
        'Accuracy': val_accuracy,
        'ROC AUC': val_roc_auc
    }
    
    # Output a classification report for each model
    print(f"{name} Classification Report:")
    print(classification_report(y_val, val_preds))
    
    # Capture loss curves for models that support it
    if name in ['XGBClassifier', 'LGBMClassifier', 'GradientBoostingClassifier']:
        print(f"Capturing loss curves for {name}...")
        
        # Train the best model with eval_set to capture training and validation loss
        if name == 'XGBClassifier':
            best_models[name].fit(X_train_data, y_train, eval_set=[(X_train_data, y_train), (X_val_data, y_val)], 
                           verbose=False)
            results = best_models[name].evals_result()
            train_loss = results['validation_0']['mlogloss']
            val_loss = results['validation_1']['mlogloss']

        elif name == 'LGBMClassifier':
            best_models[name].fit(X_train_df, y_train, eval_set=[(X_train_df, y_train), (X_val_df, y_val)], 
                           eval_metric='multi_logloss')
            results = best_models[name].evals_result_
            train_loss = results['training']['multi_logloss']
            val_loss = results['valid_1']['multi_logloss']

        elif name == 'GradientBoostingClassifier':
            best_models[name].fit(X_train_data, y_train)
            train_loss = best_models[name].train_score_
            # Calculate validation loss manually
            val_loss = []
            for y_pred in best_models[name].staged_predict_proba(X_val_data):
                val_loss.append(log_loss(y_val, y_pred))
        
        # Store loss curves
        loss_curves[name] = {
            'Training Loss': train_loss,
            'Validation Loss': val_loss
        }
    
    # Compute and store confusion matrix
    cm = confusion_matrix(y_val, val_preds)
    confusion_matrices[name] = cm
    
    # Compute and store ROC curve data
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    n_classes = len(np.unique(y_val))
    
    for i in range(n_classes):
        fpr[i], tpr[i], _ = roc_curve(y_val == i, val_probs[:, i])
        roc_auc[i] = auc(fpr[i], tpr[i])
    
    roc_curves[name] = {
        'fpr': fpr,
        'tpr': tpr,
        'roc_auc': roc_auc
    }

# Convert the metrics dictionary to a DataFrame for easy viewing
metrics_df = pd.DataFrame(model_metrics).T

# Print the DataFrame containing accuracy and AUC for each model
print(metrics_df)
# Out:
# Training DecisionTree with hyperparameter tuning...
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# DecisionTree Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.87        80
#            1       0.91      0.91      0.91        89
#            2       0.93      0.97      0.95        70
#
#     accuracy                           0.91       239
#    macro avg       0.91      0.91      0.91       239
# weighted avg       0.91      0.91      0.91       239
#
# Training RandomForest with hyperparameter tuning...
# Fitting 5 folds for each of 720 candidates, totalling 3600 fits
# RandomForest Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        80
#            1       1.00      0.98      0.99        89
#            2       0.97      1.00      0.99        70
#
#     accuracy                           0.98       239
#    macro avg       0.98      0.98      0.98       239
# weighted avg       0.98      0.98      0.98       239
#
# Training XGBClassifier with hyperparameter tuning...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# XGBClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.95      0.96        80
#            1       1.00      0.98      0.99        89
#            2       0.95      1.00      0.97        70
#
#     accuracy                           0.97       239
#    macro avg       0.97      0.98      0.97       239
# weighted avg       0.98      0.97      0.97       239
#
# Capturing loss curves for XGBClassifier...
# Training LGBMClassifier with hyperparameter tuning...
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# LGBMClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        89
#            2       1.00      1.00      1.00        70
#
#     accuracy                           1.00       239
#    macro avg       1.00      1.00      1.00       239
# weighted avg       1.00      1.00      1.00       239
#
# Capturing loss curves for LGBMClassifier...
# Training GradientBoostingClassifier with hyperparameter tuning...
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# GradientBoostingClassifier Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.97      0.99        80
#            1       1.00      1.00      1.00        89
#            2       0.97      1.00      0.99        70
#
#     accuracy                           0.99       239
#    macro avg       0.99      0.99      0.99       239
# weighted avg       0.99      0.99      0.99       239
#
# Capturing loss curves for GradientBoostingClassifier...
# Training SVM with hyperparameter tuning...
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# SVM Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        80
#            1       1.00      1.00      1.00        89
#            2       1.00      1.00      1.00        70
#
#     accuracy                           1.00       239
#    macro avg       1.00      1.00      1.00       239
# weighted avg       1.00      1.00      1.00       239
#
#                                                                   Best Params  \
# DecisionTree                       {'max_depth': 10, 'min_samples_split': 10}
# RandomForest                {'bootstrap': False, 'max_depth': 10, 'max_fea...
# XGBClassifier               {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...
# LGBMClassifier              {'learning_rate': 0.1, 'max_depth': 4, 'n_esti...
# GradientBoostingClassifier  {'learning_rate': 0.2, 'max_depth': 3, 'n_esti...
# SVM                                               {'C': 10, 'gamma': 'scale'}
#
#                             Accuracy   ROC AUC
# DecisionTree                 0.90795  0.938917
# RandomForest                0.983264  0.999814
# XGBClassifier               0.974895  0.999461
# LGBMClassifier                   1.0       1.0
# GradientBoostingClassifier  0.991632  0.999921
# SVM                              1.0       1.0

# %%
# Extract classification reports for each model
reports = {}
for name, model in best_models.items():
    X_val_data = X_val_scaled if name == 'SVM' else X_val_df if name == 'LGBMClassifier' else X_val
    val_preds = model.predict(X_val_data)
    reports[name] = classification_report(y_val, val_preds, output_dict=True)

# Proceed with plotting only for models that were successfully evaluated
if reports:
    metrics = ['precision', 'recall', 'f1-score']
    metric_names = ['Precision', 'Recall', 'F1-Score']
    classes = ['0', '1', '2']
    class_names = ['Class 0', 'Class 1', 'Class 2']
    metric_colors = ['#1f77b4', '#ff7f0e', '#2ca02c']  # Blue, Orange, Green

    for model_name, report in reports.items():
        plt.figure(figsize=(10, 6))
        x = np.arange(len(classes))
        width = 0.25

        for i, (metric, metric_name) in enumerate(zip(metrics, metric_names)):
            values = [report[cls][metric] for cls in classes]
            plt.bar(x + i * width, values, width, label=metric_name, color=metric_colors[i])

        plt.title(f'{model_name} Performance Metrics', fontsize=14, pad=20)
        plt.xticks(x + width, class_names)
        plt.ylim(0.7, 1.02)
        plt.ylabel('Score', fontsize=12)
        plt.grid(axis='y', linestyle='--', alpha=0.3)
        plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

        for i, (metric, metric_name) in enumerate(zip(metrics, metric_names)):
            values = [report[cls][metric] for cls in classes]
            for j, v in enumerate(values):
                plt.text(x[j] + i * width, v + 0.01, f'{v:.2f}', ha='center', va='bottom', fontsize=9)

        plt.tight_layout()
        plt.show()

# %%
# Plot loss curves after capturing all metrics
for name, losses in loss_curves.items():
    plt.figure(figsize=(8, 6))
    plt.plot(losses['Training Loss'], label='Training Loss')
    if losses['Validation Loss']:
        plt.plot(losses['Validation Loss'], label='Validation Loss')
    plt.xlabel('Iterations')
    plt.ylabel('Loss')
    plt.title(f'{name} Loss Curve')
    plt.legend()
    plt.show()

# %%
from sklearn.metrics import confusion_matrix

# Determine number of rows needed (ceil of total models divided by 2 for two columns)
n_models = len(confusion_matrices)
n_rows = (n_models + 1) // 2  # For an odd number of models, it will create one extra row

# Create the figure with a grid of subplots
fig, axes = plt.subplots(n_rows, 2, figsize=(8, 6 * n_rows))

# Flatten the axes array to easily iterate through
axes = axes.flatten()

# Iterate over each model's confusion matrix
for i, (name, cm) in enumerate(confusion_matrices.items()):
    ax = axes[i]  # Get the current axis
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_val), 
                yticklabels=np.unique(y_val), ax=ax)
    ax.set_title(f"Confusion Matrix for {name}")
    ax.set_xlabel('Predicted')
    ax.set_ylabel('True')

# If there's an odd number of models, remove extra subplots
for j in range(i + 1, len(axes)):
    axes[j].axis('off')  # Hide the empty subplots

plt.tight_layout()  # Adjust the layout for better spacing
plt.show()

# %%
from sklearn.metrics import confusion_matrix

# After your model evaluation loop, this will plot confusion matrices for each model
for name, cm in confusion_matrices.items():
    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(y_val), yticklabels=np.unique(y_val))
    plt.title(f"Confusion Matrix for {name}")
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

# %%
# Calculate grid dimensions dynamically
n_curves = len(roc_curves)
n_cols = 2
n_rows = int(np.ceil(n_curves / n_cols))

# Plot ROC curves in a grid-like form
plt.figure(figsize=(n_cols * 6, n_rows * 5))  # Adjust figure size based on grid
for i, (name, roc_data) in enumerate(roc_curves.items()):
    plt.subplot(n_rows, n_cols, i + 1)
    for j in range(len(roc_data['fpr'])):
        plt.plot(roc_data['fpr'][j], roc_data['tpr'][j], 
                 label=f'Class {j} (AUC = {roc_data["roc_auc"][j]:.2f})')
    plt.plot([0, 1], [0, 1], linestyle='--', color='gray')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title(f'{name} ROC Curve')
    plt.legend(loc='lower right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Interpretability of ML; Using XGBClassifier, LGBMClassifier, and RandomForest

# %%
import shap
# Initialize SHAP for each model
shap_values = {}
explainers = {}

# Models to analyze with SHAP
shap_models = {
    'XGBClassifier': best_models['XGBClassifier'],
    'LGBMClassifier': best_models['LGBMClassifier'],
    'RandomForest': best_models['RandomForest']
}

for name, model in shap_models.items():
    print(f"Performing SHAP analysis for {name}...")
    
    # Create a SHAP explainer
    explainer = shap.TreeExplainer(model)
    explainers[name] = explainer
    
    # Calculate SHAP values for the validation set
    shap_values[name] = explainer.shap_values(X_val_df)
    
    # Transpose SHAP values to (n_classes, n_samples, n_features)
    shap_values[name] = np.transpose(shap_values[name], (2, 0, 1))

     # Inspect shapes
    print(f"Shape of explainer.expected_value for {name}: {np.array(explainer.expected_value).shape}")
    print(f"Shape of shap_values for {name}: {np.array(shap_values[name]).shape}")
    print(f"Shape of X_val_df: {X_val_df.shape}")
    
    # Visualize SHAP values
    shap.initjs()  # Initialize JavaScript visualization (for force plots)
    
    # 1. Force Plot for a Single Prediction
    print(f"Force Plot for {name}:")
    for class_idx in range(len(explainer.expected_value)):
        print(f"Force Plot for {name} (Class {class_idx}):")
        shap.force_plot(
            explainer.expected_value[class_idx],  # Base value for the class
            shap_values[name][class_idx][0, :],   # SHAP values for the first instance and class
            X_val_df.iloc[0, :],                 # Feature values for the first instance
            matplotlib=True                      # Use matplotlib for rendering
        )       
    
    # Combine SHAP values for multi-class classification
    combined_shap_values = np.sum(shap_values[name], axis=0)  # Sum across all classes

    # Summary Plot (Feature Importance)
    print(f"Summary Plot for {name}:")
    shap.summary_plot(combined_shap_values, X_val_df)
    
    # Dependence Plot for a Specific Feature
    feature_index = 0  # Use the feature index instead of the name
    print(f"Dependence Plot for {name} (Feature index: {feature_index}):")
    
    # Reshape SHAP values to (n_samples * n_classes, n_features)
    reshaped_shap_values = shap_values[name].reshape(-1, shap_values[name].shape[-1])
    
    # Repeat the feature matrix for each class (n_samples * n_classes, n_features)
    reshaped_X_val_df = np.tile(X_val_df.values, (len(explainer.expected_value), 1))
    
    # Ensure that reshaped_shap_values and reshaped_X_val_df have the same number of rows
    assert reshaped_shap_values.shape[0] == reshaped_X_val_df.shape[0], (
        f"SHAP values rows: {reshaped_shap_values.shape[0]}, "
        f"Feature rows: {reshaped_X_val_df.shape[0]}"
    )
    
    # Plot the dependence plot
    shap.dependence_plot(feature_index, reshaped_shap_values, reshaped_X_val_df, interaction_index=None)
    
    # SHAP Bar Plot (Global Feature Importance)
    print(f"SHAP Bar Plot for {name}:")
    shap.summary_plot(combined_shap_values, X_val_df, plot_type="bar")
    
    # SHAP Beeswarm Plot (Detailed Feature Importance)
    print(f"SHAP Beeswarm Plot for {name}:")
    
    # Convert the SHAP values into an Explanation object
    explanation = shap.Explanation(values=combined_shap_values, 
                                   data=X_val_df.values,  # Feature data
                                   feature_names=X_val_df.columns)  # Feature names (use 'feature_names' instead of 'columns')
    
    # Now pass the Explanation object to the beeswarm plot
    shap.plots.beeswarm(explanation)
    
    print("-" * 50)
# Out:
# Performing SHAP analysis for XGBClassifier...
# Shape of explainer.expected_value for XGBClassifier: (3,)
# Shape of shap_values for XGBClassifier: (3, 239, 29459)
# Shape of X_val_df: (239, 29459)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Force Plot for XGBClassifier:
# Force Plot for XGBClassifier (Class 0):
# Force Plot for XGBClassifier (Class 1):
# Force Plot for XGBClassifier (Class 2):
# Summary Plot for XGBClassifier:
# Dependence Plot for XGBClassifier (Feature index: 0):
# SHAP Bar Plot for XGBClassifier:
# SHAP Beeswarm Plot for XGBClassifier:
# --------------------------------------------------
# Performing SHAP analysis for LGBMClassifier...
# Shape of explainer.expected_value for LGBMClassifier: (3,)
# Shape of shap_values for LGBMClassifier: (3, 239, 29459)
# Shape of X_val_df: (239, 29459)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Force Plot for LGBMClassifier:
# Force Plot for LGBMClassifier (Class 0):
# Force Plot for LGBMClassifier (Class 1):
# Force Plot for LGBMClassifier (Class 2):
# Summary Plot for LGBMClassifier:
# Dependence Plot for LGBMClassifier (Feature index: 0):
# SHAP Bar Plot for LGBMClassifier:
# SHAP Beeswarm Plot for LGBMClassifier:
# --------------------------------------------------
# Performing SHAP analysis for RandomForest...
# Shape of explainer.expected_value for RandomForest: (3,)
# Shape of shap_values for RandomForest: (3, 239, 29459)
# Shape of X_val_df: (239, 29459)
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# Force Plot for RandomForest:
# Force Plot for RandomForest (Class 0):
# Force Plot for RandomForest (Class 1):
# Force Plot for RandomForest (Class 2):
# Summary Plot for RandomForest:
# Dependence Plot for RandomForest (Feature index: 0):
# SHAP Bar Plot for RandomForest:
# SHAP Beeswarm Plot for RandomForest:
# --------------------------------------------------
